-- %%
paths.dofile('test_ucf101.lua')
-- Out:
-- {
--   nInputFrames : 5
--   datapath : /home/yu/ws_torch/dataset/UCF101/videos
--   listpath : /home/yu/ws_torch/dataset/UCF101/ucfTrainTestlist
-- }
-- {
--   1 : DoubleTensor - size: 8x5x3x224x224
-- }
-- Console does not support images
-- table: 0x4160a8c8
-- table: 0x414e8398
-- table: 0x416ff338
-- ok
